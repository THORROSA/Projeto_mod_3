# %% [markdown]
# # Hands-On
#
# Você foi designado para realizar a limpeza e preparação de dados de dois conjuntos de dados (base1.csv e base2.csv) distintos que representam informações relacionadas a risco de crédito.
#
# Seu objetivo é ler os dois conjuntos de dados usando a biblioteca Pandas, realizar a concatenação dos dados, lidar com valores duplicados e faltantes, além de verificar a presença de outliers nos dados combinados.
#
# ____
#
# ## Passos a serem seguidos:
#
# 1. **Leitura dos Arquivos:** Utilize a biblioteca Pandas para ler os dois arquivos de dados: 'base1.csv' e 'base2.csv', que estão no diretório datasets, no repositório do módulo.
# 2. **Concatenação dos Dados:** Concatene os dois conjuntos de dados em um único DataFrame, verificando se os dados possuem a mesma estrutura para uma concatenação adequada.
# 3. **Tratamento de Dados Duplicados:** Verifique se há linhas duplicadas no DataFrame combinado e remova-as, mantendo a primeira ocorrência.
# 4. **Tratamento de Valores Faltantes:** Identifique e lide com os valores faltantes no DataFrame combinado. Preencha os valores ausentes com estratégias apropriadas (média, mediana, valor específico etc.) dependendo do contexto dos dados.
# 5. **Verificação de Outliers:** Utilize métodos estatísticos ou gráficos (como boxplots) para identificar a presença de outliers nos dados. Considere se eles são significativos para a análise ou se precisam ser tratados de alguma forma.

# %%
import pandas as pd
import numpy as np

# %%
base1 = pd.read_csv('https://raw.githubusercontent.com/allansuzuki/ADA_classes/main/DS-PY-Data-Science/DS-PY-004%20T%C3%89CNICAS%20DE%20PROGRAMA%C3%87%C3%83O%20I%20(PY)/Material%20do%20Aluno/datasets/base1.csv')
base2 = pd.read_csv('https://raw.githubusercontent.com/allansuzuki/ADA_classes/main/DS-PY-Data-Science/DS-PY-004%20T%C3%89CNICAS%20DE%20PROGRAMA%C3%87%C3%83O%20I%20(PY)/Material%20do%20Aluno/datasets/base2.csv')

# %%
base1
# Out:
#      Unnamed: 0.1  Unnamed: 0  Age     Sex  Job Housing Saving accounts  \
# 0             104         104   26    male    2    rent             NaN
# 1             360         360   61    male    2    free             NaN
# 2             695         695   50    male    2    rent      quite rich
# 3             902         902   42    male    2    free             NaN
# 4             312         312   26  female    2     own          little
# ..            ...         ...  ...     ...  ...     ...             ...
# 665           456         456   36    male    2    rent          little
# 666           623         623   22  female    2    rent          little
# 667           225         225   27    male    2     own          little
# 668           874         874   29    male    1     own          little
# 669           560         560   49    male    2    free             NaN
#
#     Checking account  Credit amount  Duration              Purpose  Risk
# 0                NaN           2445        12                  car  good
# 1           moderate           1239        18            education  good
# 2                NaN           1236         6                  car  good
# 3                NaN          10477        36                  car  good
# 4               rich           3749        24  furniture/equipment  good
# ..               ...            ...       ...                  ...   ...
# 665           little           3905        11                  car  good
# 666           little           1858        12  furniture/equipment  good
# 667              NaN           2613        36              repairs  good
# 668           little           3590        12  furniture/equipment  good
# 669           little           2964        24                  car  good
#
# [670 rows x 12 columns]

# %%
base2
# Out:
#      Unnamed: 0.1  Unnamed: 0  Age     Sex  Job Housing Saving accounts  \
# 0             674         674   41    male    1     own      quite rich
# 1             983         983   26    male    2     own          little
# 2              31          31   27    male    2     own          little
# 3              50          50   29    male    1     own             NaN
# 4             654         654   35    male    2     own          little
# ..            ...         ...  ...     ...  ...     ...             ...
# 325           467         467   32    male    2     own             NaN
# 326           829         829   38    male    2    free             NaN
# 327           296         296   20  female    2    rent             NaN
# 328           235         235   30    male    3     own          little
# 329           633         633   19  female    2    rent          little
#
#     Checking account  Credit amount  Duration              Purpose  Risk
# 0                NaN           2580        21             business   bad
# 1             little           8229        36                  car   bad
# 2             little           4020        24  furniture/equipment  good
# 3           moderate           2333        24  furniture/equipment  good
# 4                NaN           2346        24                  car  good
# ..               ...            ...       ...                  ...   ...
# 325              NaN           7238        48             radio/TV  good
# 326         moderate           6681        48             business  good
# 327              NaN           4675        12                  car  good
# 328           little           1823        24             radio/TV   bad
# 329              NaN           1980         9  furniture/equipment   bad
#
# [330 rows x 12 columns]

# %%
base3 = pd.concat([base1,base2],ignore_index=True)

# %%
base3
# Out:
#      Unnamed: 0.1  Unnamed: 0  Age     Sex  Job Housing Saving accounts  \
# 0             104         104   26    male    2    rent             NaN
# 1             360         360   61    male    2    free             NaN
# 2             695         695   50    male    2    rent      quite rich
# 3             902         902   42    male    2    free             NaN
# 4             312         312   26  female    2     own          little
# ..            ...         ...  ...     ...  ...     ...             ...
# 995           467         467   32    male    2     own             NaN
# 996           829         829   38    male    2    free             NaN
# 997           296         296   20  female    2    rent             NaN
# 998           235         235   30    male    3     own          little
# 999           633         633   19  female    2    rent          little
#
#     Checking account  Credit amount  Duration              Purpose  Risk
# 0                NaN           2445        12                  car  good
# 1           moderate           1239        18            education  good
# 2                NaN           1236         6                  car  good
# 3                NaN          10477        36                  car  good
# 4               rich           3749        24  furniture/equipment  good
# ..               ...            ...       ...                  ...   ...
# 995              NaN           7238        48             radio/TV  good
# 996         moderate           6681        48             business  good
# 997              NaN           4675        12                  car  good
# 998           little           1823        24             radio/TV   bad
# 999              NaN           1980         9  furniture/equipment   bad
#
# [1000 rows x 12 columns]

# %%
base3.nunique()
# Out:
# Unnamed: 0.1        1000
# Unnamed: 0          1000
# Age                   53
# Sex                    2
# Job                    4
# Housing                3
# Saving accounts        4
# Checking account       3
# Credit amount        921
# Duration              33
# Purpose                8
# Risk                   2
# dtype: int64

# %%
base3.drop_duplicates()
# Out:
#      Unnamed: 0.1  Unnamed: 0  Age     Sex  Job Housing Saving accounts  \
# 0             104         104   26    male    2    rent             NaN
# 1             360         360   61    male    2    free             NaN
# 2             695         695   50    male    2    rent      quite rich
# 3             902         902   42    male    2    free             NaN
# 4             312         312   26  female    2     own          little
# ..            ...         ...  ...     ...  ...     ...             ...
# 995           467         467   32    male    2     own             NaN
# 996           829         829   38    male    2    free             NaN
# 997           296         296   20  female    2    rent             NaN
# 998           235         235   30    male    3     own          little
# 999           633         633   19  female    2    rent          little
#
#     Checking account  Credit amount  Duration              Purpose  Risk
# 0                NaN           2445        12                  car  good
# 1           moderate           1239        18            education  good
# 2                NaN           1236         6                  car  good
# 3                NaN          10477        36                  car  good
# 4               rich           3749        24  furniture/equipment  good
# ..               ...            ...       ...                  ...   ...
# 995              NaN           7238        48             radio/TV  good
# 996         moderate           6681        48             business  good
# 997              NaN           4675        12                  car  good
# 998           little           1823        24             radio/TV   bad
# 999              NaN           1980         9  furniture/equipment   bad
#
# [1000 rows x 12 columns]

# %%
base3.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0          Age          Job  Credit amount  \
# count   1000.000000  1000.000000  1000.000000  1000.000000    1000.000000
# mean     499.500000   499.500000    35.546000     1.904000    3271.258000
# std      288.819436   288.819436    11.375469     0.653614    2822.736876
# min        0.000000     0.000000    19.000000     0.000000     250.000000
# 25%      249.750000   249.750000    27.000000     2.000000    1365.500000
# 50%      499.500000   499.500000    33.000000     2.000000    2319.500000
# 75%      749.250000   749.250000    42.000000     2.000000    3972.250000
# max      999.000000   999.000000    75.000000     3.000000   18424.000000
#
#           Duration
# count  1000.000000
# mean     20.903000
# std      12.058814
# min       4.000000
# 25%      12.000000
# 50%      18.000000
# 75%      24.000000
# max      72.000000

# %%
base3.isnull().sum()
# Out:
# Unnamed: 0.1          0
# Unnamed: 0            0
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# Risk                  0
# dtype: int64

# %%
base3['Checking account'].fillna("nao preenchidos",inplace = True)
base3['Saving accounts'].fillna("nao preenchidos",inplace = True)
base3
# Out:
#      Unnamed: 0.1  Unnamed: 0  Age     Sex  Job Housing  Saving accounts  \
# 0             104         104   26    male    2    rent  nao preenchidos
# 1             360         360   61    male    2    free  nao preenchidos
# 2             695         695   50    male    2    rent       quite rich
# 3             902         902   42    male    2    free  nao preenchidos
# 4             312         312   26  female    2     own           little
# ..            ...         ...  ...     ...  ...     ...              ...
# 995           467         467   32    male    2     own  nao preenchidos
# 996           829         829   38    male    2    free  nao preenchidos
# 997           296         296   20  female    2    rent  nao preenchidos
# 998           235         235   30    male    3     own           little
# 999           633         633   19  female    2    rent           little
#
#     Checking account  Credit amount  Duration              Purpose  Risk
# 0    nao preenchidos           2445        12                  car  good
# 1           moderate           1239        18            education  good
# 2    nao preenchidos           1236         6                  car  good
# 3    nao preenchidos          10477        36                  car  good
# 4               rich           3749        24  furniture/equipment  good
# ..               ...            ...       ...                  ...   ...
# 995  nao preenchidos           7238        48             radio/TV  good
# 996         moderate           6681        48             business  good
# 997  nao preenchidos           4675        12                  car  good
# 998           little           1823        24             radio/TV   bad
# 999  nao preenchidos           1980         9  furniture/equipment   bad
#
# [1000 rows x 12 columns]

# %%
import matplotlib as mpl

# %%
boxplot = base3.boxplot(by = 'Sex',column = 'Credit amount')
boxplot
# Out:
# <AxesSubplot:title={'center':'Credit amount'}, xlabel='Sex'>
